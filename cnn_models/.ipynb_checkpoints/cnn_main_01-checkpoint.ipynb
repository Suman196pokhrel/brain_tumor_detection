# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow.keras import models ,layers, preprocessing
import cv2 as cv
import PIL
from PIL import Image
import os
import glob
import io
# Out:
# 2022-02-10 08:17:23.830434: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-02-10 08:17:23.830463: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %% [markdown]
# # Image conversion to numerical array

# %% [markdown]
# Fetching dataset into the program

# %%
img_dir = "../data/"
no_tumor_images = os.listdir(img_dir + "no/")
yes_tumor_images = os.listdir(img_dir + "yes/")

# %%
dataset = []
labels = []

# %%
def show_image_from_path(img):
    print(img)
    pil_image = Image.open(img)
    plt.figure(figsize=(10,10))
    plt.imshow(np.array(pil_image))
    
def show_image_from_array(arr):
    plt.figure(figsize=(10,10))
    plt.imshow(arr)

# %%
def image_preprocessing(img):
#     show_image_from_path(img)
    image1 = cv.imread(img,0)
    image1 = cv.convertScaleAbs(image1, alpha=0.1, beta=0.2)
    plt.imshow(image1)

# %%
image_preprocessing(img_dir+'no/'+no_tumor_images[0])

# %%
for image_name in no_tumor_images:
    image = cv.imread(img_dir + 'no/'+image_name,0)
    image = Image.fromarray(image, 'RGB')
    image = image.resize((64,64))
    dataset.append(np.array(image))
    labels.append(0)

# %%
for image_name in yes_tumor_images:
    image = cv.imread(img_dir + 'yes/'+ image_namem,0)
    image = Image.fromarray(image, 'RGB')
    image = image.resize((64,64))
    dataset.append(np.array(image))
    labels.append(1)

# %%
data_1 = np.asanyarray(dataset)
l = np.asarray(labels)
# Out:
# /tmp/ipykernel_5081/1394372080.py:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   data_1 = np.asanyarray(dataset)

# %%
data_1.shape , l.shape, data_1.ndim, l.ndim
# Out:
# ((6000,), (6000,), 1, 1)

# %%
plt.imshow(data_1[3])

# %% [markdown]
# # Model training
